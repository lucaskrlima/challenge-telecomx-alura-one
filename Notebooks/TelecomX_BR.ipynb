# %% [markdown]
# #📌 Extracão

# %%
# Importando bibliotecas padrão
import requests
import json
import pandas as pd

# %%
# Carregando os dados da API
url = 'https://raw.githubusercontent.com/ingridcristh/challenge2-data-science/main/TelecomX_Data.json'
dados_telecomx = requests.get(url)

# Adicionando os dados em uma variável
dados = json.loads(dados_telecomx.text)

# %%
# Exibindo os dados
pd.DataFrame(dados)
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
# Convertendo e normalizando os dados em um dataframe
dados_normalizado = pd.json_normalize(dados, sep='_')

dados_normalizado
# Out:
#       customerID Churn customer_gender  customer_SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %% [markdown]
# #🔧 Transformação

# %% [markdown]
# ## *Conhecendo o Dataset*

# %%
# Explorando as colunas do Dataset e verificando os tipos de dados
dados_normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer_gender            7267 non-null   object
#  3   customer_SeniorCitizen     7267 non-null   int64
#  4   customer_Partner           7267 non-null   object
#  5   customer_Dependents        7267 non-null   object
#  6   customer_tenure            7267 non-null   int64
#  7   phone_PhoneService         7267 non-null   object
#  8   phone_MultipleLines        7267 non-null   object
#  9   internet_InternetService   7267 non-null   object
#  10  internet_OnlineSecurity    7267 non-null   object
#  11  internet_OnlineBackup      7267 non-null   object
#  12  internet_DeviceProtection  7267 non-null   object
# ...

# %%
# Verificando quantidade de linhas e colunas do dataset
dados_normalizado.shape
# Out:
# (7267, 21)

# %%
# Identificado as colunas
# Consultar o dicionário para mais informações
dados_normalizado.columns
# Out:
# Index(['customerID', 'Churn', 'customer_gender', 'customer_SeniorCitizen',
#        'customer_Partner', 'customer_Dependents', 'customer_tenure',
#        'phone_PhoneService', 'phone_MultipleLines', 'internet_InternetService',
#        'internet_OnlineSecurity', 'internet_OnlineBackup',
#        'internet_DeviceProtection', 'internet_TechSupport',
#        'internet_StreamingTV', 'internet_StreamingMovies', 'account_Contract',
#        'account_PaperlessBilling', 'account_PaymentMethod',
#        'account_Charges_Monthly', 'account_Charges_Total'],
#       dtype='object')

# %%
# Verificando o tipo de dados de cada coluna
dados_normalizado.dtypes
# Out:
# customerID                    object
# Churn                         object
# customer_gender               object
# customer_SeniorCitizen         int64
# customer_Partner              object
# customer_Dependents           object
# customer_tenure                int64
# phone_PhoneService            object
# phone_MultipleLines           object
# internet_InternetService      object
# internet_OnlineSecurity       object
# internet_OnlineBackup         object
# internet_DeviceProtection     object
# internet_TechSupport          object
# internet_StreamingTV          object
# internet_StreamingMovies      object
# account_Contract              object
# account_PaperlessBilling      object
# account_PaymentMethod         object
# account_Charges_Monthly      float64
# account_Charges_Total         object
# dtype: object

# %%
# Explorando algumas colunas que possuem dados numericos
dados_normalizado[['customerID','customer_SeniorCitizen', 'customer_tenure', 'account_Charges_Monthly']]
# Out:
#       customerID  customer_SeniorCitizen  customer_tenure  \
# 0     0002-ORFBO                       0                9
# 1     0003-MKNFE                       0                9
# 2     0004-TLHLJ                       0                4
# 3     0011-IGKFF                       1               13
# 4     0013-EXCHZ                       1                3
# ...          ...                     ...              ...
# 7262  9987-LUTYD                       0               13
# 7263  9992-RRAMN                       0               22
# 7264  9992-UJOEL                       0                2
# 7265  9993-LHIEB                       0               67
# 7266  9995-HOTOH                       0               63
#
#       account_Charges_Monthly
# 0                       65.60
# 1                       59.90
# 2                       73.90
# 3                       98.00
# 4                       83.90
# ...                       ...
# 7262                    55.15
# ...

# %%
# Explorando as colunas do tipo object
dados_normalizado[['customerID','customer_gender', 'Churn']]
# Out:
#       customerID customer_gender Churn
# 0     0002-ORFBO          Female    No
# 1     0003-MKNFE            Male    No
# 2     0004-TLHLJ            Male   Yes
# 3     0011-IGKFF            Male   Yes
# 4     0013-EXCHZ          Female   Yes
# ...          ...             ...   ...
# 7262  9987-LUTYD          Female    No
# 7263  9992-RRAMN            Male   Yes
# 7264  9992-UJOEL            Male    No
# 7265  9993-LHIEB            Male    No
# 7266  9995-HOTOH            Male    No
#
# [7267 rows x 3 columns]

# %%
# Verificando as colunas referentes a assinaturas e contratos
'''
PhoneService: assinatura de serviço telefônico
MultipleLines: assisnatura de mais de uma linha de telefone
InternetService: assinatura de um provedor internet
OnlineSecurity: assinatura adicional de segurança online
OnlineBackup: assinatura adicional de backup online
DeviceProtection: assinatura adicional de proteção no dispositivo
TechSupport: assinatura adicional de suporte técnico, menos tempo de espera
StreamingTV: assinatura de TV a cabo
StreamingMovies: assinatura de streaming de filmes
'''
dados_normalizado[['phone_PhoneService', 'phone_MultipleLines', 'internet_InternetService', 'internet_OnlineSecurity',
                   'internet_OnlineBackup', 'internet_DeviceProtection', 'internet_TechSupport', 'internet_StreamingTV',
                   'internet_StreamingMovies']]
# Out:
#      phone_PhoneService phone_MultipleLines internet_InternetService  \
# 0                   Yes                  No                      DSL
# 1                   Yes                 Yes                      DSL
# 2                   Yes                  No              Fiber optic
# 3                   Yes                  No              Fiber optic
# 4                   Yes                  No              Fiber optic
# ...                 ...                 ...                      ...
# 7262                Yes                  No                      DSL
# 7263                Yes                 Yes              Fiber optic
# 7264                Yes                  No                      DSL
# 7265                Yes                  No                      DSL
# 7266                 No    No phone service                      DSL
#
#      internet_OnlineSecurity internet_OnlineBackup internet_DeviceProtection  \
# ...

# %%
dados_normalizado
# Out:
#      id_cliente churn customer_gender  cidadao_senior  parceiro  dependentes  \
# 0     0002ORFBO     0          Female               0         1            1
# 1     0003MKNFE     0            Male               0         0            0
# 2     0004TLHLJ     1            Male               0         0            0
# 3     0011IGKFF     1            Male               1         1            0
# 4     0013EXCHZ     1          Female               1         1            0
# ...         ...   ...             ...             ...       ...          ...
# 7262  9987LUTYD     0          Female               0         0            0
# 7263  9992RRAMN     1            Male               0         1            0
# 7264  9992UJOEL     0            Male               0         0            0
# 7265  9993LHIEB     0            Male               0         1            1
# 7266  9995HOTOH     0            Male               0         1            1
#
# ...

# %% [markdown]
# ## *Verificando Inconsistências nos Dados*

# %%
#Verificando existência de dados nulos
dados_normalizado.isnull().sum()
# Out:
# customerID                   0
# Churn                        0
# customer_gender              0
# customer_SeniorCitizen       0
# customer_Partner             0
# customer_Dependents          0
# customer_tenure              0
# phone_PhoneService           0
# phone_MultipleLines          0
# internet_InternetService     0
# internet_OnlineSecurity      0
# internet_OnlineBackup        0
# internet_DeviceProtection    0
# internet_TechSupport         0
# internet_StreamingTV         0
# internet_StreamingMovies     0
# account_Contract             0
# account_PaperlessBilling     0
# account_PaymentMethod        0
# account_Charges_Monthly      0
# account_Charges_Total        0
# dtype: int64

# %%
# Convertendo a coluna account_Charges_Total para float
dados_normalizado['account_Charges_Total'] = pd.to_numeric(dados_normalizado['account_Charges_Total'], errors='coerce')

# %%
#Visualizando os dados com a conversão da coluna account_Charges_Total
dados_normalizado.dtypes
# Out:
# customerID                    object
# Churn                         object
# customer_gender               object
# customer_SeniorCitizen         int64
# customer_Partner              object
# customer_Dependents           object
# customer_tenure                int64
# phone_PhoneService            object
# phone_MultipleLines           object
# internet_InternetService      object
# internet_OnlineSecurity       object
# internet_OnlineBackup         object
# internet_DeviceProtection     object
# internet_TechSupport          object
# internet_StreamingTV          object
# internet_StreamingMovies      object
# account_Contract              object
# account_PaperlessBilling      object
# account_PaymentMethod         object
# account_Charges_Monthly      float64
# account_Charges_Total        float64
# dtype: object

# %%
#Tratandos algumas inconsistências deixando todos os nomes das colunas em minúsculos
dados_normalizado.columns = dados_normalizado.columns.str.lower()

# %%
#Tratando os dados de customer id, retirando o -
dados_normalizado.customerid.unique()
# Out:
# array(['0002-ORFBO', '0003-MKNFE', '0004-TLHLJ', ..., '9992-UJOEL',
#        '9993-LHIEB', '9995-HOTOH'], dtype=object)

# %%
dados_normalizado['customerid'] = dados_normalizado['customerid'].str.replace('-', '')

# %%
dados_normalizado.customerid.unique()
# Out:
# array(['0002ORFBO', '0003MKNFE', '0004TLHLJ', ..., '9992UJOEL',
#        '9993LHIEB', '9995HOTOH'], dtype=object)

# %%
#Renomeando os nomes das colunas
nome_colunas_atualizadas = {

    'customerid': 'id_cliente',
    'customer_seniorcitizen': 'cidadao_senior',
    'customer_partner': 'parceiro',
    'customer_dependents': 'dependentes',
    'customer_tenure': 'meses_contrato',
    'phone_phoneservice': 'servico_telefone',
    'phone_multiplelines': 'multiplas_linhas',
    'internet_internetservice': 'servico_internet',
    'internet_onlinesecurity': 'seguranca_online',
    'internet_onlineBackup': 'backup_online',
    'internet_deviceoprotection': 'protecao_dispositivo',
    'internet_techsupport': 'suporte_tecnico',
    'internet_streamingtv': 'streaming_tv',
    'internet_StreamingMovies': 'streaming_filmes',
    'account_contract': 'contrato',
    'account_paperlessbilling': 'fatura_online',
    'account_paymentmethod': 'metodo_pagamento',
    'account_charges_monthly': 'gastos_mensais',
    'account_charges_total': 'gastos_totais'
}

# %%
dados_normalizado.rename(columns=nome_colunas_atualizadas, inplace=True)
dados_normalizado.columns.unique()
# Out:
# Index(['id_cliente', 'churn', 'customer_gender', 'cidadao_senior', 'parceiro',
#        'dependentes', 'meses_contrato', 'servico_telefone', 'multiplas_linhas',
#        'servico_internet', 'seguranca_online', 'internet_onlinebackup',
#        'internet_deviceprotection', 'suporte_tecnico', 'streaming_tv',
#        'internet_streamingmovies', 'contrato', 'fatura_online',
#        'metodo_pagamento', 'gastos_mensais', 'gastos_totais'],
#       dtype='object')

# %%
#Cria uma coluna conta_diaria que contém o gasto diário com base em gastos_mensais
dados_normalizado['contas_diarias'] = dados_normalizado['gastos_mensais'] / 30

# %%
dados_normalizado[['id_cliente', 'gastos_mensais', 'contas_diarias']]
# Out:
#      id_cliente  gastos_mensais  contas_diarias
# 0     0002ORFBO           65.60        2.186667
# 1     0003MKNFE           59.90        1.996667
# 2     0004TLHLJ           73.90        2.463333
# 3     0011IGKFF           98.00        3.266667
# 4     0013EXCHZ           83.90        2.796667
# ...         ...             ...             ...
# 7262  9987LUTYD           55.15        1.838333
# 7263  9992RRAMN           85.10        2.836667
# 7264  9992UJOEL           50.30        1.676667
# 7265  9993LHIEB           67.85        2.261667
# 7266  9995HOTOH           59.00        1.966667
#
# [7267 rows x 3 columns]

# %% [markdown]
# #📊 Carga e análise

# %% [markdown]
# ## *Análise* *Descritiva*

# %%
#Calculando média, mediana e desvio padrão com método describe
dados_normalizado.describe()
# Out:
#        cidadao_senior     parceiro  dependentes  meses_contrato  \
# count     7267.000000  7267.000000  7267.000000     7267.000000
# mean         0.162653     0.484106     0.300124       32.346498
# std          0.369074     0.499782     0.458343       24.571773
# min          0.000000     0.000000     0.000000        0.000000
# 25%          0.000000     0.000000     0.000000        9.000000
# 50%          0.000000     0.000000     0.000000       29.000000
# 75%          0.000000     1.000000     1.000000       55.000000
# max          1.000000     1.000000     1.000000       72.000000
#
#        servico_telefone  fatura_online  gastos_mensais  gastos_totais  \
# count       7267.000000    7267.000000     7267.000000    7256.000000
# mean           0.902711       0.593230       64.720098    2280.634213
# std            0.296371       0.491265       30.129572    2268.632997
# min            0.000000       0.000000       18.250000      18.800000
# ...

# %%
#Distribuição de evasão entre clientes e servico_internet
import seaborn as sns
import matplotlib.pyplot as plt

#Criando um gráfico de contagem para distribuição de churn
sns.countplot(x='servico_internet', hue='churn', data=dados_normalizado, palette='viridis')

#Títulos e rótulos
plt.title('Distribuição de churn por Serviço de internet')
plt.xlabel('Serviço de internet')
plt.ylabel('Contagem de clientes')
plt.legend(title='Churn', labels=['Não', 'Sim'])

plt.show()

# %%
#Distribuiçãod e gastos mensais por churn

#Cria um box plot para Gastos mensais x Churn
sns.boxplot(x='churn', y='gastos_mensais', data=dados_normalizado, palette='pastel')

plt.title('Distribuição de gastos mensais por churn')
plt.xlabel('Churn')
plt.ylabel('Gastos mensais')

plt.show()
# Out:
# /tmp/ipython-input-546088870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='churn', y='gastos_mensais', data=dados_normalizado, palette='pastel')

# %%
#Contagem de evasão por uma variável categórica usando metodo de tabela cruzada
proporcao_por_genero = pd.crosstab(dados_normalizado['customer_gender'], dados_normalizado['churn'], normalize='index')
print(proporcao_por_genero)
# Out:
# churn                   0         1
# customer_gender
# Female           0.709633  0.261414  0.028953
# Male             0.714286  0.253061  0.032653

# %%
'''
Contagem e evasão por variáveis numéricas

Boxplot de distribuição de gastos totais por evasão
'''
#Definindo o tamanho do gráfico
plt.figure(figsize=(10,6))

#Criando boxplot
sns.boxplot(x='churn', y='gastos_mensais', data=dados_normalizado, palette='pastel')

#Rótulos e títulos
plt.title('Distribuição de gastos totais por evasão(churn)')
plt.xlabel('Evasão')
plt.ylabel('Gastos totais')

plt.show()
# Out:
# /tmp/ipython-input-3338938749.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='churn', y='gastos_mensais', data=dados_normalizado, palette='pastel')

# %%
#Definindo o tamanho do gráfico
plt.figure(figsize=(10,6))

#Criando gráfico de densidade
sns.kdeplot(x='meses_contrato', hue='churn', data=dados_normalizado, fill=True, common_norm=False)

#Rótulos e títulos
plt.title('Distribuição de meses de contrato por evasão(churn)')
plt.xlabel('Meses de contrato')
plt.ylabel('Densidade')

plt.show()

# %% [markdown]
# #📄Relatorio Final

# %% [markdown]
# ## Introdução
#
# Este relatório apresenta uma análise detalhada dos dados de clientes com o objetivo de identificar os principais fatores que contribuem para a evasão de clientes, também conhecida como "churn". O problema de churn é crucial para qualquer negócio, pois a retenção de clientes é fundamental para a saúde financeira e o crescimento sustentável. A análise exploratória de dados (EDA) foi utilizada para descobrir padrões, comportamentos e características dos clientes que evadiram em comparação com aqueles que permaneceram.

# %% [markdown]
# ## Limpeza e Tratamento de Dados
#
# Antes de iniciar a análise, foi necessário realizar uma série de etapas de limpeza e tratamento de dados para garantir a qualidade e a confiabilidade dos resultados. As principais ações realizadas foram:
#
# Padronização de Colunas: Os nomes das colunas foram renomeados do formato original (customerID0Churn0customer_gender0, etc.) para nomes mais claros e em português (ID_Cliente, Churn, Gênero, etc.).
#
# Conversão de Tipos: A coluna de gastos totais, que estava como tipo object, foi convertida para float. Durante esse processo, valores não numéricos (provavelmente strings vazias ou espaços) foram substituídos por NaN (Not a Number), permitindo a conversão sem erros.
#
# Criação de Novas Colunas: Uma nova coluna, contas_diarias, foi criada para calcular o gasto diário de cada cliente, dividindo o gasto mensal por 30 (média de dias no mês).
#
# Codificação de Variáveis: As colunas com valores categóricos binários (Sim/Não) foram convertidas para o formato numérico (1/0), facilitando análises e futuras modelagens.

# %% [markdown]
# ## Análise Exploratória de Dados
#
# A análise exploratória revelou insights importantes sobre o comportamento dos clientes e a sua relação com a evasão. As principais descobertas foram:
#
# A.1. Distribuição de Evasão por Variáveis Categóricas
# Análises de contagem e gráficos de barras mostraram a distribuição de churn entre diferentes categorias de clientes.
#
# Evasão por Serviço de Internet: Clientes com Fibra Ótica apresentaram uma taxa de evasão visivelmente maior do que clientes com DSL ou sem serviço de internet, indicando uma possível insatisfação com a qualidade ou o custo-benefício desse serviço.
#
# Evasão por Contrato: A taxa de evasão é significativamente maior em contratos de curto prazo (mês a mês). Clientes com contratos de um ou dois anos demonstram uma probabilidade muito menor de churn, sugerindo que o vínculo contratual é um forte fator de retenção.
#
# A.2. Distribuição de Variáveis Numéricas e a Evasão
# Análises de box plot e gráficos de densidade foram utilizadas para entender como as variáveis numéricas se distribuem entre os grupos que evadiram e os que não evadiram.
#
# Gastos Mensais: Os clientes que evadiram tendem a ter gastos mensais mais elevados em comparação com os que permaneceram. O gráfico de densidade mostrou um pico de evasão em faixas de gastos mensais mais altas, o que pode estar relacionado ao custo elevado dos serviços.
#
# Tempo de Contrato (Tenure): A distribuição do tempo de contrato é o fator mais revelador. Clientes com curto tempo de contrato (de 1 a 10 meses) possuem uma probabilidade de evasão muito maior, enquanto a evasão é quase nula para clientes com contratos de longa duração. Isso sugere que o início do relacionamento é o período mais crítico.
#
# A.3. Correlação entre Variáveis
# A análise de correlação quantificou a relação entre as variáveis, reforçando os insights visuais.
#
# Relação com Evasão (Churn): A correlação mais forte com a evasão foi observada para Gastos_Mensais e o Tempo de Contrato, confirmando que esses são os fatores numéricos que mais influenciam o churn.
#
# Relação entre Serviços: O Gasto_Mensal tem uma forte correlação positiva com o número de serviços contratados, o que é esperado.

# %% [markdown]
# ## Conclusões e Insights
#
# As análises realizadas revelaram que a evasão de clientes não é um evento aleatório, mas sim um comportamento previsível, fortemente ligado a certas características e padrões de consumo.
#
# Os principais gatilhos de evasão são:
#
# Curto tempo de relacionamento com a empresa.
#
# Gastos mensais mais elevados, especialmente para clientes com serviços de alta velocidade (Fibra Ótica).
#
# Contratos de curta duração (mês a mês).
#
# A falta de segurança, proteção e suporte técnico também se mostrou relevante. Clientes que não assinam serviços como Seguranca_Online ou Suporte_Tecnico são mais propensos a evadir.
